# %%
import pandas as pd

# %%
f = r'c:\wd64759\db\stock_sh_20181025.xlsx'
datas = pd.read_excel(f)

# %%
datas.columns
# Out:
# Index(['代码', '名称', '涨幅%', '现价', '涨跌', '买价', '卖价', '总量', '现量', '涨速%', '换手%',
#        '今开', '最高', '最低', '昨收', '市盈(动)', '总金额', '量比'],
#       dtype='object')

# %%
# datas.sort_index(axis=1,ascending=False)
datas.loc[:,['名称', '涨幅%']]
# Out:
#          名称   涨幅%
# 0      平安银行  1.85
# 1      万 科Ａ  1.99
# 2      国农科技  --
# 3      世纪星源  1.08
# 4      深振业Ａ  0.59
# 5       全新好 -0.35
# 6      神州高铁  0.74
# 7      中国宝安  0.77
# 8      美丽生态     0
# 9      深物业A  0.22
# 10     南 玻Ａ  0.73
# 11     沙河股份 -1.04
# 12     深康佳Ａ     0
# 13     深中华A  0.46
# 14     神州长城  2.59
# 15     深深宝Ａ  1.17
# 16     深华发Ａ -0.19
# 17      深科技     0
# 18     深赤湾Ａ -3.02
# 19     深天地Ａ -3.85
# 20     特 力Ａ  0.11
# 21     飞亚达Ａ -0.42
# 22     深圳能源     0
# 23     国药一致     0
# 24     深深房Ａ  --
# 25     富奥股份  0.28
# 26     中粮地产  --
# 27     深桑达Ａ   1.2
# 28     神州数码 -1.04
# 29     中国天楹  1.36
# ...     ...   ...
# 3530   益丰药房     0
# 3531   大千生态  -0.8
# 3532   哈森股份 -1.56
# 3533   百利科技 -1.24
# 3534   克来机电 -1.89
# 3535   大理药业  0.16
# 3536   法兰泰克  0.51
# 3537   醋化股份  1.07
# 3538   银龙股份     0
# 3539   中农立华 -2.54
# 3540   正川股份 -0.31
# 3541   国泰集团  0.75
# 3542   深圳新星 -3.74
# 3543    金诚信  3.04
# 3544   吉华集团  1.07
# 3545   恒润股份 -1.22
# 3546   兆易创新 -3.43
# 3547    康德莱 -0.54
# ...
