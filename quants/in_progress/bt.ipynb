# %%
from datetime import datetime
import backtrader as bt

# %%
data = bt.feeds.YahooFinanceData(dataname='MSFT',
                                 fromdate=datetime(2019, 1, 1),
                                 todate=datetime(2020, 1, 31))

# %%
dir(data)
# Out:
# ['CONNBROKEN',
#  'CONNECTED',
#  'Close',
#  'DELAYED',
#  'DISCONNECTED',
#  'DateTime',
#  'High',
#  'IndType',
#  'LIVE',
#  'LineOrder',
#  'Low',
#  'NOTSUBSCRIBED',
#  'NOTSUPPORTED_TF',
#  'ObsType',
#  'Open',
#  'OpenInterest',
#  'StratType',
#  'UNKNOWN',
#  'Volume',
#  '_NOTIFNAMES',
#  '_OwnerCls',
#  '__abs__',
#  '__add__',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__pow__',
#  '__radd__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmul__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '_add2stack',
#  '_barstack',
#  '_barstash',
#  '_check',
#  '_clone',
#  '_compensate',
#  '_compression',
#  '_dataname',
#  '_feed',
#  '_ffilters',
#  '_filters',
#  '_fromstack',
#  '_getline',
#  '_getnexteos',
#  '_getnextline',
#  '_getstatusname',
#  '_gettz',
#  '_gettzinput',
#  '_last',
#  '_load',
#  '_loadline',
#  '_makeoperation',
#  '_makeoperationown',
#  '_minperiod',
#  '_name',
#  '_operation',
#  '_operation_stage1',
#  '_operation_stage2',
#  '_operationown',
#  '_operationown_stage1',
#  '_operationown_stage2',
#  '_opstage',
#  '_owner',
#  '_plotlabel',
#  '_qcheck',
#  '_roperation',
#  '_save2stack',
#  '_stage1',
#  '_stage2',
#  '_start',
#  '_start_finish',
#  '_started',
#  '_store',
#  '_tick_fill',
#  '_tick_nullify',
#  '_timeframe',
#  '_timeoffset',
#  '_tmoffset',
#  '_updatebar',
#  'addfilter',
#  'addfilter_simple',
#  'addminperiod',
#  'advance',
#  'advance_peek',
#  'alias',
#  'aliased',
#  'array',
#  'backwards',
#  'clone',
#  'compensate',
#  'copyas',
#  'csv',
#  'date2num',
#  'do_qcheck',
#  'extend',
#  'f',
#  'forward',
#  'frompackages',
#  'get_notifications',
#  'getenvironment',
#  'getfeed',
#  'getwriterheaders',
#  'getwriterinfo',
#  'getwritervalues',
#  'haslivedata',
#  'home',
#  'incminperiod',
#  'islive',
#  'l',
#  'line',
#  'line0',
#  'line1',
#  'line2',
#  'line3',
#  'line4',
#  'line5',
#  'line6',
#  'line7',
#  'line_0',
#  'line_1',
#  'line_2',
#  'line_3',
#  'line_4',
#  'line_5',
#  'line_6',
#  'line_7',
#  'linealias',
#  'lines',
#  'load',
#  'minbuffer',
#  'next',
#  'nextstart',
#  'notifs',
#  'num2date',
#  'once',
#  'oncestart',
#  'p',
#  'packages',
#  'params',
#  'plotinfo',
#  'plotlabel',
#  'plotlines',
#  'preload',
#  'prenext',
#  'preonce',
#  'put_notification',
#  'qbuffer',
#  'replay',
#  'replaying',
#  'resample',
#  'resampling',
#  'reset',
#  'rewind',
#  'setenvironment',
#  'setminperiod',
#  'start',
#  'start_v7',
#  'stop',
#  'updateminperiod']

# %%
help(data)
# Out:
# Help on YahooFinanceData in module backtrader.feeds.yahoo object:
#
# class YahooFinanceData(YahooFinanceCSVData)
#  |  YahooFinanceData(*args, **kwargs)
#  |
#  |  Executes a direct download of data from Yahoo servers for the given time
#  |  range.
#  |
#  |  Specific parameters (or specific meaning):
#  |
#  |    - ``dataname``
#  |
#  |      The ticker to download ('YHOO' for Yahoo own stock quotes)
#  |
#  |    - ``proxies``
#  |
#  |      A dict indicating which proxy to go through for the download as in
#  |      {'http': 'http://myproxy.com'} or {'http': 'http://127.0.0.1:8080'}
#  |
#  |    - ``period``
#  |
#  |      The timeframe to download data in. Pass 'w' for weekly and 'm' for
#  |      monthly.
#  |
#  |    - ``reverse``
#  |
#  |      [2018-11-16] The latest incarnation of Yahoo online downloads returns
#  |      the data in the proper order. The default value of ``reverse`` for the
#  |      online download is therefore set to ``False``
#  |
#  |    - ``adjclose``
#  |
#  |      Whether to use the dividend/split adjusted close and adjust all values
#  |      according to it.
#  |
#  |    - ``urlhist``
#  |
#  |      The url of the historical quotes in Yahoo Finance used to gather a
#  |      ``crumb`` authorization cookie for the download
#  |
#  |    - ``urldown``
#  |
#  |      The url of the actual download server
#  |
#  |    - ``retries``
#  |
#  |      Number of times (each) to try to get a ``crumb`` cookie and download
#  |      the data
#  |
#  |  Method resolution order:
#  |      YahooFinanceData
#  |      YahooFinanceCSVData
#  |      backtrader.feed.CSVDataBase
#  |      backtrader.feed.DataBase
#  |      backtrader.feed.AbstractDataBase
#  |      backtrader.dataseries.OHLCDateTime
#  |      backtrader.dataseries.OHLC
#  |      backtrader.dataseries.DataSeries
#  |      backtrader.lineseries.LineSeries
#  |      backtrader.lineroot.LineMultiple
#  |      backtrader.lineroot.LineRoot
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  start(self)
#  |
#  |  start_v7(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  alias = ()
#  |
#  |  aliased = ''
#  |
#  |  frompackages = ()
#  |
#  |  linealias = <class 'backtrader.metabase.AutoInfoClass_la_Lin...Base_la...
#  |
#  |
#  |  lines = <class 'backtrader.lineseries.Lines_LineSeries_D...SVDataBase_...
#  |      Defines an "array" of lines which also has most of the interface of
#  |      a LineBuffer class (forward, rewind, advance...).
#  |
#  |      This interface operations are passed to the lines held by self
#  |
#  |      The class can autosubclass itself (_derive) to hold new lines keeping them
#  |      in the defined order.
#  |
#  |  packages = ()
#  |
#  |  params = <class 'backtrader.metabase.AutoInfoClass_LineRo...SVDataBase...
#  |
#  |
#  |  plotinfo = <class 'backtrader.metabase.AutoInfoClass_pi_Lin...Base_pi_...
#  |
#  |
#  |  plotlines = <class 'backtrader.metabase.AutoInfoClass_pl_Lin...Base_pl...
#  |
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from backtrader.feed.CSVDataBase:
#  |
#  |  preload(self)
#  |
#  |  stop(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from backtrader.feed.CSVDataBase:
#  |
#  |  f = None
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from backtrader.feed.AbstractDataBase:
#  |
#  |  addfilter(self, p, *args, **kwargs)
#  |
#  |  addfilter_simple(self, f, *args, **kwargs)
#  |
#  |  advance(self, size=1, datamaster=None, ticks=True)
#  |
#  |  advance_peek(self)
#  |
#  |  clone(self, **kwargs)
#  |
#  |  compensate(self, other)
#  |      Call it to let the broker know that actions on this asset will
#  |      compensate open positions in another
#  |
#  |  copyas(self, _dataname, **kwargs)
#  |
#  |  date2num(self, dt)
#  |
#  |  do_qcheck(self, onoff, qlapse)
#  |
#  |  get_notifications(self)
#  |      Return the pending "store" notifications
#  |
#  |  getenvironment(self)
#  |
#  |  getfeed(self)
#  |
#  |  haslivedata(self)
#  |
#  |  islive(self)
#  |      If this returns True, ``Cerebro`` will deactivate ``preload`` and
#  |      ``runonce`` because a live data source must be fetched tick by tick (or
#  |      bar by bar)
#  |
#  |  load(self)
#  |
#  |  next(self, datamaster=None, ticks=True)
#  |      Called to calculate values when the minperiod is over
#  |
#  |  num2date(self, dt=None, tz=None, naive=True)
#  |
#  |  put_notification(self, status, *args, **kwargs)
#  |      Add arguments to notification queue
#  |
#  |  qbuffer(self, savemem=0, replaying=False)
#  |      Change the lines to implement a minimum size qbuffer scheme
#  |
#  |  replay(self, **kwargs)
#  |
#  |  resample(self, **kwargs)
#  |
#  |  setenvironment(self, env)
#  |      Keep a reference to the environment
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from backtrader.feed.AbstractDataBase:
#  |
#  |  CONNBROKEN = 2
#  |
#  |  CONNECTED = 0
#  |
#  |  DELAYED = 3
#  |
#  |  DISCONNECTED = 1
#  |
#  |  LIVE = 4
#  |
#  |  NOTSUBSCRIBED = 5
#  |
#  |  NOTSUPPORTED_TF = 6
#  |
#  |  UNKNOWN = 7
#  |
#  |  replaying = 0
#  |
#  |  resampling = 0
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from backtrader.dataseries.DataSeries:
#  |
#  |  getwriterheaders(self)
#  |
#  |  getwriterinfo(self)
#  |
#  |  getwritervalues(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from backtrader.dataseries.DataSeries:
#  |
#  |  Close = 0
#  |
#  |  DateTime = 6
#  |
#  |  High = 2
#  |
#  |  LineOrder = [6, 3, 2, 1, 0, 4, 5]
#  |
#  |  Low = 1
#  |
#  |  Open = 3
#  |
#  |  OpenInterest = 5
#  |
#  |  Volume = 4
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from backtrader.lineseries.LineSeries:
#  |
#  |  __call__(self, ago=None, line=-1)
#  |      Returns either a delayed verison of itself in the form of a
#  |      LineDelay object or a timeframe adapting version with regards to a ago
#  |
#  |      Param: ago (default: None)
#  |
#  |        If ago is None or an instance of LineRoot (a lines object) the
#  |        returned valued is a LineCoupler instance
#  |
#  |        If ago is anything else, it is assumed to be an int and a LineDelay
#  |        object will be returned
#  |
#  |      Param: line (default: -1)
#  |        If a LinesCoupler will be returned ``-1`` means to return a
#  |        LinesCoupler which adapts all lines of the current LineMultiple
#  |        object. Else the appropriate line (referenced by name or index) will
#  |        be LineCoupled
#  |
#  |        If a LineDelay object will be returned, ``-1`` is the same as ``0``
#  |        (to retain compatibility with the previous default value of 0). This
#  |        behavior will change to return all existing lines in a LineDelayed
#  |        form
#  |
#  |        The referenced line (index or name) will be LineDelayed
#  |
#  |  __getattr__(self, name)
#  |
#  |  __getitem__(self, key)
#  |
#  |  __init__(self, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __len__(self)
#  |
#  |  __setitem__(self, key, value)
#  |
#  |  backwards(self, size=1, force=False)
#  |
#  |  extend(self, value=nan, size=0)
#  |
#  |  forward(self, value=nan, size=1)
#  |      # The operations below have to be overriden to make sure subclasses can
#  |      # reach them using "super" which will not call __getattr__ and
#  |      # LineSeriesStub (see below) already uses super
#  |
#  |  home(self)
#  |
#  |  plotlabel(self)
#  |
#  |  reset(self)
#  |
#  |  rewind(self, size=1)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from backtrader.lineseries.LineSeries:
#  |
#  |  array
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from backtrader.lineseries.LineSeries:
#  |
#  |  csv = True
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from backtrader.lineroot.LineMultiple:
#  |
#  |  addminperiod(self, minperiod)
#  |      The passed minperiod is fed to the lines
#  |
#  |  incminperiod(self, minperiod)
#  |      The passed minperiod is fed to the lines
#  |
#  |  minbuffer(self, size)
#  |      Receive notification of how large the buffer must at least be
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from backtrader.lineroot.LineRoot:
#  |
#  |  __abs__(self)
#  |
#  |  __add__(self, other)
#  |
#  |  __bool__ = __nonzero__(self)
#  |
#  |  __div__(self, other)
#  |
#  |  __eq__(self, other)
#  |      Return self==value.
#  |
#  |  __floordiv__(self, other)
#  |
#  |  __ge__(self, other)
#  |      Return self>=value.
#  |
#  |  __gt__(self, other)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __le__(self, other)
#  |      Return self<=value.
#  |
#  |  __lt__(self, other)
#  |      Return self<value.
#  |
#  |  __mul__(self, other)
#  |
#  |  __ne__(self, other)
#  |      Return self!=value.
#  |
#  |  __neg__(self)
#  |
#  |  __nonzero__(self)
#  |
#  |  __pow__(self, other)
#  |
#  |  __radd__(self, other)
#  |
#  |  __rdiv__(self, other)
#  |
#  |  __rfloordiv__(self, other)
#  |
#  |  __rmul__(self, other)
#  |
#  |  __rpow__(self, other)
#  |
#  |  __rsub__(self, other)
#  |
#  |  __rtruediv__(self, other)
#  |
#  |  __sub__(self, other)
#  |
#  |  __truediv__(self, other)
#  |
#  |  nextstart(self)
#  |      It will be called when the minperiod phase is over for the 1st
#  |      post-minperiod value. Only called once and defaults to automatically
#  |      calling next
#  |
#  |  once(self, start, end)
#  |      Called to calculate values at "once" when the minperiod is over
#  |
#  |  oncestart(self, start, end)
#  |      It will be called when the minperiod phase is over for the 1st
#  |      post-minperiod value
#  |
#  |      Only called once and defaults to automatically calling once
#  |
#  |  prenext(self)
#  |      It will be called during the "minperiod" phase of an iteration.
#  |
#  |  preonce(self, start, end)
#  |      It will be called during the "minperiod" phase of a "once" iteration
#  |
#  |  setminperiod(self, minperiod)
#  |      Direct minperiod manipulation. It could be used for example
#  |      by a strategy
#  |      to not wait for all indicators to produce a value
#  |
#  |  updateminperiod(self, minperiod)
#  |      Update the minperiod if needed. The minperiod will have been
#  |      calculated elsewhere
#  |      and has to take over if greater that self's
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from backtrader.lineroot.LineRoot:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from backtrader.lineroot.LineRoot:
#  |
#  |  IndType = 0
#  |
#  |  ObsType = 2
#  |
#  |  StratType = 1
